# %%
import os
import django
from django.contrib.auth import get_user_model
import requests

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'blog.settings')
os.environ.setdefault('DJANGO_ALLOW_ASYNC_UNSAFE', 'true')
django.setup()

# %%
from article.models import Post, Comment

User = get_user_model()
user = User.objects.get(id=1)
Post.objects.all()
# Out:
# (0.144) SELECT "auth_user"."id", "auth_user"."password", "auth_user"."last_login", "auth_user"."is_superuser", "auth_user"."username", "auth_user"."first_name", "auth_user"."last_name", "auth_user"."email", "auth_user"."is_staff", "auth_user"."is_active", "auth_user"."date_joined" FROM "auth_user" WHERE "auth_user"."id" = 1 LIMIT 21; args=(1,)
# (0.001) SELECT "article_post"."id", "article_post"."author_id", "article_post"."title", "article_post"."body", "article_post"."status", "article_post"."slug", "article_post"."created", "article_post"."updated" FROM "article_post" ORDER BY "article_post"."created" ASC LIMIT 21; args=()
# ...

# %%
url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
data[0]
# Out:
# {'userId': 1,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#  'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
Post.objects.all().delete()
posts = {}
for post in data:
    p = Post.objects.create(title=post["title"], body=post["body"], author=user, slug=post["title"])
    posts[post["id"]] = p.id
# Out:
# (0.001) SELECT "article_post"."id", "article_post"."author_id", "article_post"."title", "article_post"."body", "article_post"."status", "article_post"."slug", "article_post"."created", "article_post"."updated" FROM "article_post"; args=()
# (0.000) BEGIN; args=None
# ...

# %%
url = "https://jsonplaceholder.typicode.com/comments"
response = requests.get(url)

# %%
data = response.json()
data[50]
# Out:
# {'postId': 11,
#  'id': 51,
#  'name': 'molestias et odio ut commodi omnis ex',
#  'email': 'Laurie@lincoln.us',
#  'body': 'perferendis omnis esse\nvoluptate sit mollitia sed perferendis\nnemo nostrum qui\nvel quis nisi doloribus animi odio id quas'}

# %%
Comment.objects.all().delete()
for comment in data:
    Comment.objects.create(author=user, 
                           body=comment["body"], 
                           post=Post.objects.get(id=posts[comment["postId"]]))
# Out:
# (0.000) BEGIN; args=None
# (0.009) DELETE FROM "article_comment"; args=()
# (0.001) SELECT "article_post"."id", "article_post"."author_id", "article_post"."title", "article_post"."body", "article_post"."status", "article_post"."slug", "article_post"."created", "article_post"."updated" FROM "article_post" WHERE "article_post"."id" = 802 LIMIT 21; args=(802,)
# (0.148) INSERT INTO "article_comment" ("post_id", "author_id", "likes_count", "dislikes_count", "body", "created", "updated") VALUES (802, 1, 0, 0, 'laudantium enim quasi est quidem magnam voluptate ipsam eos
# tempora quo necessitatibus
# dolor quam autem quasi
# reiciendis et nam sapiente accusantium', '2021-03-03 14:45:47.070281', '2021-03-03 14:45:47.070451'); args=[802, 1, 0, 0, 'laudantium enim quasi est quidem magnam voluptate ipsam eos\ntempora quo necessitatibus\ndolor quam autem quasi\nreiciendis et nam sapiente accusantium', '2021-03-03 14:45:47.070281', '2021-03-03 14:45:47.070451']
# ...

# %%
from django.db.models import Count, F, Concat
from article.models import Like
# qs = Post.objects.filter(id__range=[0,910]).values("id", "title").aggregate(comments_count=Count("comment"), likes_count=Count("likes"))

# cqs = Comment.objects.filter(author__icontains="us").values_list("post_id", flat=True)
qs = Post.objects.filter(id__range=[280,910]).annotate(dt = Concat(F("created__date"),Value("|"), F("id"),output_field=CharField()))
for i in qs:
    print(i.created)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-44180e6b32ad> in <module>
# ----> 1 from django.db.models import Count, F, Concat
#       2 from article.models import Like
#       3 # qs = Post.objects.filter(id__range=[0,910]).values("id", "title").aggregate(comments_count=Count("comment"), likes_count=Count("likes"))
#       4
#       5 # cqs = Comment.objects.filter(author__icontains="us").values_list("post_id", flat=True)
#
# ImportError: cannot import name 'Concat' from 'django.db.models' (/home/denta/Datawiz/3.03.2021/Blog/.venv/lib/python3.8/site-packages/django/db/models/__init__.py)

# %%
qs.update()
